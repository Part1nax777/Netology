# %%
cook_book = {
'салат': [
{'ingridient_name': 'сыр', 'quantity': 50, 'measure': 'гр'},
{'ingridient_name': 'томаты', 'quantity': 2, 'measure': 'шт'},
{'ingridient_name': 'огурцы', 'quantity': 20, 'measure': 'гр'},
{'ingridient_name': 'маслины', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'оливковое масло', 'quantity': 20, 'measure': 'мл'},
{'ingridient_name': 'салат', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'перец', 'quantity': 20, 'measure': 'гр'}
],
'пицца': [
{'ingridient_name': 'сыр', 'quantity': 20, 'measure': 'гр'},
{'ingridient_name': 'колбаса', 'quantity': 30, 'measure': 'гр'},
{'ingridient_name': 'бекон', 'quantity': 30, 'measure': 'гр'},
{'ingridient_name': 'оливки', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'томаты', 'quantity': 20, 'measure': 'гр'},
{'ingridient_name': 'тесто', 'quantity': 100, 'measure': 'гр'},
],
'лимонад': [
{'ingridient_name': 'лимон', 'quantity': 1, 'measure': 'шт'},
{'ingridient_name': 'вода', 'quantity': 200, 'measure': 'мл'},
{'ingridient_name': 'сахар', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'лайм', 'quantity': 20, 'measure': 'гр'},
]
}

quantity = int(input('Введите количество порций: '))
dishes_keys = cook_book.keys()
dishes = tuple(names)
total_hash = {}

number_dish = 0
ingridients = 0
while number_dish < len(dishes):
    while ingridients < len(cook_book[name[number_dish]]):
        total_ingr = (
            cook_book[name[number_dish]][ingridients]['ingridient_name'], 
            cook_book[name[number_dish]][ingridients]['quantity'] * quantity, 
            cook_book[name[number_dish]][ingridients]['measure']
        )
        total_ingr = list(total_ingr) 
        print(list(total_hash.values()))
        if total_ingr[0] not in total_hash: #and total_ingr[2] != total_hash[total_ingr[2]]: 
            total_hash[total_ingr[0]] = total_ingr 
        else:
            total_hash[total_ingr[0]] += total_ingr
        ingridients += 1
    ingridients = 0
    number_dish += 1
    
print(total_hash)   
for key, value in total_hash.items():
    
    print(f'{key}: {value}')
# Out:
# Введите количество порций: 1
# []
# [['сыр', 50, 'гр']]
# [['сыр', 50, 'гр'], ['томаты', 2, 'шт']]
# [['сыр', 50, 'гр'], ['томаты', 2, 'шт'], ['огурцы', 20, 'гр']]
# [['сыр', 50, 'гр'], ['томаты', 2, 'шт'], ['огурцы', 20, 'гр'], ['маслины', 10, 'гр']]
# [['сыр', 50, 'гр'], ['томаты', 2, 'шт'], ['огурцы', 20, 'гр'], ['маслины', 10, 'гр'], ['оливковое масло', 20, 'мл']]
# [['сыр', 50, 'гр'], ['томаты', 2, 'шт'], ['огурцы', 20, 'гр'], ['маслины', 10, 'гр'], ['оливковое масло', 20, 'мл'], ['салат', 10, 'гр']]
# [['сыр', 50, 'гр'], ['томаты', 2, 'шт'], ['огурцы', 20, 'гр'], ['маслины', 10, 'гр'], ['оливковое масло', 20, 'мл'], ['салат', 10, 'гр'], ['перец', 20, 'гр']]
# [['сыр', 50, 'гр', 'сыр', 20, 'гр'], ['томаты', 2, 'шт'], ['огурцы', 20, 'гр'], ['маслины', 10, 'гр'], ['оливковое масло', 20, 'мл'], ['салат', 10, 'гр'], ['перец', 20, 'гр']]
# ...
